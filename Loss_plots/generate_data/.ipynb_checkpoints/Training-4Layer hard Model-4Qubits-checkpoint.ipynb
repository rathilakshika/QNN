# %%
from adam import ADAM
from qiskit import QuantumCircuit
from qiskit.circuit.library import RealAmplitudes, ZFeatureMap
import numpy as np
from qiskit.quantum_info import Statevector
from math import log

# %%
# size of training data set
training_size = 100
# dimension of data sets
n = 4
from sklearn import datasets
from sklearn import preprocessing
iris = datasets.load_iris()
# load iris and normalise
x = preprocessing.normalize(iris.data)
x1_train = x[0:49, :] # class A
x2_train = x[50:99, :] # class B
training_input = {'A':x1_train, 'B':x2_train}
class_labels = ['A', 'B']

# %%
sv = Statevector.from_label('0' * n)

# %%
def final_circuit(circuit, data, params):
    for i in range(n):
        circuit.h(i)
        circuit.rz(data[i], i)
    
    for i in range(n-1):
        for j in range(i+1, n):
            circuit.cx(i, j)
            circuit.rz((np.pi-data[i])*(np.pi-data[j]), j)
            circuit.cx(i, j)
            circuit.barrier()
            
    for i in range(n):
        circuit.ry(params[i],i)
    
    for i in range(n-1):
        for j in range(i+1, n):
            circuit.cx(i,j)
    circuit.barrier()
    
    for i in range(n):
        circuit.rz(data[i], i)
    
    for i in range(n-1):
        for j in range(i+1, n):
            circuit.cx(i, j)
            circuit.rz((np.pi-data[i])*(np.pi-data[j]), j)
            circuit.cx(i, j)
            circuit.barrier()
            
    for i in range(n):
        circuit.ry(params[i+4],i)
        
    for i in range(n-1):
        for j in range(i+1, n):
            circuit.cx(i,j)
    circuit.barrier()
    
    for i in range(n):
        circuit.rz(data[i], i)
    
    for i in range(n-1):
        for j in range(i+1, n):
            circuit.cx(i, j)
            circuit.rz((np.pi-data[i])*(np.pi-data[j]), j)
            circuit.cx(i, j)
            circuit.barrier()
            
    for i in range(n):
        circuit.ry(params[i+8],i)
        
    for i in range(n-1):
        for j in range(i+1, n):
            circuit.cx(i,j)
    circuit.barrier()
    
    for i in range(n):
        circuit.rz(data[i], i)
    
    for i in range(n-1):
        for j in range(i+1, n):
            circuit.cx(i, j)
            circuit.rz((np.pi-data[i])*(np.pi-data[j]), j)
            circuit.cx(i, j)
            circuit.barrier()
            
    for i in range(n):
        circuit.ry(params[i+12],i)

# %%
cir = QuantumCircuit(n)
final_circuit(cir, x[0], [-1,1,1,-1,2,4,6,8,1,1,1,1,0,0,0,0])
cir.draw('mpl')

# %%
def assign_label(bit_string, class_labels):
    hamming_weight = sum([int(k) for k in list(bit_string)])
    is_odd_parity = hamming_weight & 1
    if is_odd_parity:
        return class_labels[1]
    else:
        return class_labels[0]

def return_probabilities(counts, class_labels):
    shots = sum(counts.values())
    result = {class_labels[0]: 0,
              class_labels[1]: 0}
    for key, item in counts.items():
        label = assign_label(key, class_labels)
        result[label] += counts[key]/shots
    return result

def classify(x_list, params, class_labels):
    qc_list = []
    for x in x_list:
        circuit = QuantumCircuit(n)
        circ_ = final_circuit(circuit, x, params)
        qc = sv.evolve(circuit)
        qc_list += [qc]
    probs = []
    for qc in qc_list:
        counts = qc.probabilities_dict()
        prob = return_probabilities(counts, class_labels)
        probs += [prob]
    return probs


def CrossEntropy(yHat, y):
    if y == 'A':
      return -log(yHat['A'])
    else:
      return -log(1-yHat['A'])


def cost_function(training_input, class_labels, params, shots=100, print_value=False):
    # map training input to list of labels and list of samples
    cost = 0
    training_labels = []
    training_samples = []
    for label, samples in training_input.items():
        for sample in samples:
            training_labels += [label]
            training_samples += [sample]

    # classify all samples
    probs = classify(training_samples, params, class_labels)

    # evaluate costs for all classified samples
    for i, prob in enumerate(probs):
        cost += CrossEntropy(yHat=prob, y=training_labels[i])
    cost /= len(training_samples)

    # return objective value
    #print(cost)
    return cost


# setup the optimizer
optimizer = ADAM(maxiter=100, lr=0.1)

# define objective function for training
objective_function = lambda params: cost_function(training_input, class_labels, params, print_value=True)

d = 16   # num of trainable params
for i in range(99,100,1):
    print(i)
    np.random.seed(i)
    # randomly initialize the parameters
    init_params = np.random.uniform(-1,1,d)
    print(init_params)
    # train classifier
    #init_params = np.random.uniform(-1,1,2)
    opt_params, value, _, loss = optimizer.optimize(len(init_params), objective_function, initial_point=init_params)
    print(loss)
    print(opt_params)
    f1 = 'quantum_loss_hard_layer4_%d.npy' %i
    f2 = 'opt_params_hard_layer4_%d.npy'%i
    np.save(f2, opt_params)
    np.save(f1, loss)
# Out:
# 99
# [ 0.34455712 -0.0238432   0.65099035 -0.93710722  0.61609993  0.13123484
#  -0.404755   -0.90660856  0.9812548  -0.98634853  0.53958606  0.4935342
#  -0.24512213 -0.0117051   0.85789678 -0.20909191]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-8703e0e6059b> in <module>
#      76     # train classifier
#      77     #init_params = np.random.uniform(-1,1,2)
# ---> 78     opt_params, value, _, loss = optimizer.optimize(len(init_params), objective_function, initial_point=init_params)
#      79     print(loss)
#      80     print(opt_params)
#
# ~/QNN/Loss_plots/generate_data/adam/adam.py in optimize(self, num_vars, objective_function, gradient_function, variable_bounds, initial_point)
#     151                                                         (objective_function, self._eps))
#     152
# --> 153         point, value, nfev = self.minimize(objective_function, initial_point, gradient_function)
#     154         return point, value, nfev, self.loss_list
#
# ~/QNN/Loss_plots/generate_data/adam/adam.py in minimize(self, objective_function, initial_point, gradient_function)
#     115         params = params_new = initial_point
#     116         while self._t < self._maxiter:
# --> 117             derivative = gradient_function(params)
#     118             self._t += 1
#     119             self._m = self._beta_1 * self._m + (1 - self._beta_1) * derivative
#
# ~/.local/lib/python3.7/site-packages/qiskit/aqua/components/optimizers/optimizer.py in function_wrapper(*wrapper_args)
#     130         """
#     131         def function_wrapper(*wrapper_args):
# --> 132             return function(*(wrapper_args + args))
#     133         return function_wrapper
#     134
#
# ~/.local/lib/python3.7/site-packages/qiskit/aqua/components/optimizers/optimizer.py in gradient_num_diff(x_center, f, epsilon, max_evals_grouped)
#     109         for chunk in chunks:  # eval the chunks in order
#     110             parallel_parameters = np.concatenate(chunk)
# --> 111             todos_results = f(parallel_parameters)  # eval the points in a chunk (order preserved)
#     112             if isinstance(todos_results, float):
#     113                 grad.append((todos_results - forig) / epsilon)
#
# <ipython-input-7-8703e0e6059b> in <lambda>(params)
#      65
#      66 # define objective function for training
# ---> 67 objective_function = lambda params: cost_function(training_input, class_labels, params, print_value=True)
#      68
#      69 d = 16   # num of trainable params
#
# <ipython-input-7-8703e0e6059b> in cost_function(training_input, class_labels, params, shots, print_value)
#      49
#      50     # classify all samples
# ---> 51     probs = classify(training_samples, params, class_labels)
#      52
#      53     # evaluate costs for all classified samples
#
# <ipython-input-7-8703e0e6059b> in classify(x_list, params, class_labels)
#      21         circuit = QuantumCircuit(n)
#      22         circ_ = final_circuit(circuit, x, params)
# ---> 23         qc = sv.evolve(circuit)
#      24         qc_list += [qc]
#      25     probs = []
#
# ~/.local/lib/python3.7/site-packages/qiskit/quantum_info/states/statevector.py in evolve(self, other, qargs)
#     229             if self.num_qubits is None:
#     230                 raise QiskitError("Cannot apply QuantumCircuit to non-qubit Statevector.")
# --> 231             return self._evolve_instruction(ret, other, qargs=qargs)
#     232
#     233         # Evolution by an Operator
#
# ~/.local/lib/python3.7/site-packages/qiskit/quantum_info/states/statevector.py in _evolve_instruction(statevec, obj, qargs)
#     688             else:
#     689                 new_qargs = [qargs[tup.index] for tup in qregs]
# --> 690             Statevector._evolve_instruction(statevec, instr, qargs=new_qargs)
#     691         return statevec
#
# ~/.local/lib/python3.7/site-packages/qiskit/quantum_info/states/statevector.py in _evolve_instruction(statevec, obj, qargs)
#     655         from qiskit.circuit.barrier import Barrier
#     656
# --> 657         mat = Operator._instruction_to_matrix(obj)
#     658         if mat is not None:
#     659             # Perform the composition and inplace update the current state
#
# ~/.local/lib/python3.7/site-packages/qiskit/quantum_info/operators/operator.py in _instruction_to_matrix(cls, obj)
#     503             # `to_matrix` definition and if so use that.
#     504             try:
# --> 505                 mat = obj.to_matrix()
#     506             except QiskitError:
#     507                 pass
#
# ~/.local/lib/python3.7/site-packages/qiskit/circuit/library/standard_gates/rz.py in to_matrix(self)
#     106         import numpy as np
#     107         ilam2 = 0.5j * float(self.params[0])
# --> 108         return np.array([[np.exp(-ilam2), 0],
#     109                          [0, np.exp(ilam2)]], dtype=complex)
#     110
#
# KeyboardInterrupt:

# %%
loss_eqnn_d1 = np.load('Data/4Layers/Layer4Hard4q/quantum_loss_hard_layer4_1.npy')

# %%
loss_eqnn_d1.shape
# Out:
# (100,)

# %%
loss = np.zeros((100,100))
for i in range(99):
    file = 'Data/4Layers/Layer4Hard4q/quantum_loss_hard_layer4_%d.npy'%i
    loss[i] += np.load(file, allow_pickle=True)

# %%
loss[99] = loss[98]
loss
# Out:
# array([[0.6349984 , 0.53527062, 0.45117557, ..., 0.09695299, 0.09633513,
#         0.09567118],
#        [0.54173695, 0.44243065, 0.36185842, ..., 0.07741331, 0.07713066,
#         0.07682141],
#        [0.59354086, 0.50534678, 0.44190652, ..., 0.10010382, 0.10008369,
#         0.10006513],
#        ...,
#        [0.60249648, 0.52763812, 0.4490739 , ..., 0.07762645, 0.07753305,
#         0.07745153],
#        [0.61063601, 0.49348881, 0.4024371 , ..., 0.10577648, 0.10551799,
#         0.10522888],
#        [0.61063601, 0.49348881, 0.4024371 , ..., 0.10577648, 0.10551799,
#         0.10522888]])

# %%
import matplotlib.pyplot as plt
groen = np.array([0,208,0])/255
stddevs =[]
averages =[]
sd = np.std(loss, axis=0)
av = np.average(loss, axis=0)
plt.plot(range(100), av)
plt.fill_between(range(100), av+np.array(sd), av-np.array(sd), alpha=0.1)
stddevs.append(sd)
averages.append(av)

plt.xlabel("Number of Iterations")
plt.ylabel("Loss")
plt.title("Training - 4 Layers (Data Reuploading, Qubits = 4, Hard Model)")
# Out:
# Text(0.5, 1.0, 'Training - 4 Layers (Data Reuploading, Qubits = 4, Hard Model)')

# %%
losseasy = np.zeros((100,100))
for i in range(100):
    file = 'Data/4Layers/Layer4Easy4q/quantum_loss_easy_layer44q_%d.npy'%i
    losseasy[i] += np.load(file, allow_pickle=True)

# %%
stddevs =[]
averages =[]
sde = np.std(losseasy, axis=0)
ave = np.average(losseasy, axis=0)
plt.plot(range(100), ave)
plt.fill_between(range(100), ave+np.array(sde), ave-np.array(sde), alpha=0.1)
stddevs.append(sde)
averages.append(ave)

plt.plot(range(100), av)
plt.fill_between(range(100), av+np.array(sd), av-np.array(sd), alpha=0.1)

plt.xlabel("Number of Iterations")
plt.ylabel("Loss")
plt.title("Training - 4 Layer (Data Reuploading, Qubits = 4)")

legendList = ['{}'.format(i) for i in ["Easy Model", "Hard Model"]]
plt.legend(legendList)
