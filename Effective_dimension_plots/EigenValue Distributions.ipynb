# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate

rooi = np.array([255, 29, 0])/255
blou = np.array([0, 150, 236])/255
groen = np.array([0,208,0])/255

# %%
fhat_1layer = np.load("2qubits_1layer_f_hats_pauli.npy")

e1=[]

for i in range(100):
    e1.append(np.linalg.eigh(fhat_1layer[i])[0])

e1 = np.average(e1, axis=0)

counts, bins = np.histogram(e1, bins=np.linspace(np.min(e1), np.max(e1), 5))
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative)
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("1 Layer, Easy Model")
# Out:
# Text(0.5, 1.0, '1 Layer, Easy Model')

# %%
fhat_1layerh = np.load("2qubits_1layerhard_f_hats_pauli.npy")

e1h=[]

for i in range(100):
    e1h.append(np.linalg.eigh(fhat_1layerh[i])[0])

e1h = np.average(e1h, axis=0)

counts, bins = np.histogram(e1h, bins=np.linspace(np.min(e1h), np.max(e1h), 5))
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative)
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("1 Layer, Hard Model")
# Out:
# Text(0.5, 1.0, '1 Layer, Hard Model')

# %%
fhat_2layer = np.load("2qubits_2layer_f_hats_pauli.npy")

e2=[]

for i in range(100):
    e2.append(np.linalg.eigh(fhat_2layer[i])[0])

e2 = np.average(e2, axis=0)

counts, bins = np.histogram(e2, bins=np.linspace(np.min(e2), np.max(e2), 5))
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative)
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("2 Layer, Easy Model")
# Out:
# Text(0.5, 1.0, '2 Layer, Easy Model')

# %%
fhat_2layerh = np.load("2qubits_2layerhard_f_hats_pauli.npy")

e2h=[]

for i in range(100):
    e2h.append(np.linalg.eigh(fhat_2layerh[i])[0])

e2h = np.average(e2h, axis=0)

counts, bins = np.histogram(e2h, bins=np.linspace(np.min(e2h), np.max(e2h), 5))
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative)
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("2 Layers, Hard Model")
# Out:
# Text(0.5, 1.0, '2 Layers, Hard Model')

# %%
fhat_3layer = np.load("2qubits_3layer_f_hats_pauli.npy")

e3=[]

for i in range(100):
    e3.append(np.linalg.eigh(fhat_3layer[i])[0])

e3 = np.average(e3, axis=0)

counts, bins = np.histogram(e3, bins=np.linspace(np.min(e3), np.max(e3), 5))
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative)
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("3 Layer, Easy Model")
# Out:
# Text(0.5, 1.0, '3 Layer, Easy Model')

# %%
fhat_3layerh = np.load("2qubits_3layerhard_f_hats_pauli.npy")

e3h=[]

for i in range(100):
    e3h.append(np.linalg.eigh(fhat_3layerh[i])[0])

e3h = np.average(e3h, axis=0)

counts, bins = np.histogram(e3h, bins=np.linspace(np.min(e3h), np.max(e3h), 5))
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative)
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("3 Layers, Hard Model")
# Out:
# Text(0.5, 1.0, '3 Layers, Hard Model')

# %%
fhat_4layer = np.load("2qubits_4layer_f_hats_pauli.npy")

e4=[]

for i in range(100):
    e4.append(np.linalg.eigh(fhat_4layer[i])[0])

e4 = np.average(e4, axis=0)

counts, bins = np.histogram(e4, bins=np.linspace(np.min(e4), np.max(e4), 5))
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative)
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("4 Layers, Easy Model")
# Out:
# Text(0.5, 1.0, '4 Layers, Easy Model')

# %%
fhat_4layerh = np.load("2qubits_4layerhard_f_hats_pauli.npy")

e4h=[]

for i in range(100):
    e4h.append(np.linalg.eigh(fhat_4layerh[i])[0])

e4h = np.average(e4h, axis=0)

counts, bins = np.histogram(e4h, bins=np.linspace(np.min(e4h), np.max(e4h), 5))
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative)
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("4 Layers, Hard Model")
# Out:
# Text(0.5, 1.0, '4 Layers, Hard Model')

# %%
fhat_5layer = np.load("2qubits_5layer_f_hats_pauli.npy")

e5=[]

for i in range(100):
    e5.append(np.linalg.eigh(fhat_5layer[i])[0])

e5 = np.average(e5, axis=0)

counts, bins = np.histogram(e5, bins=np.linspace(np.min(e5), np.max(e5), 5))
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative)
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("5 Layers, Easy Model")
# Out:
# Text(0.5, 1.0, '5 Layers, Easy Model')

# %%
fhat_5layerh = np.load("2qubits_5layerhard_f_hats_pauli.npy")

e5h=[]

for i in range(100):
    e5h.append(np.linalg.eigh(fhat_5layerh[i])[0])

e5h = np.average(e5h, axis=0)

counts, bins = np.histogram(e5h, bins=np.linspace(np.min(e5h), np.max(e5h), 5))
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative)
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("5 Layers, Hard Model")
# Out:
# Text(0.5, 1.0, '5 Layers, Hard Model')

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
counts, bins = np.histogram(e1, bins=[0,0.5,1,1.5,2])
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative,align='edge')
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("1 Layer, Easy Model")

plt.subplot(1,2,2)
counts, bins = np.histogram(e1h, bins=[0,0.5,1,1.5,2])
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative,align='edge')
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("1 Layer, Hard Model")
# Out:
# Text(0.5, 1.0, '1 Layer, Hard Model')

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
counts, bins = np.histogram(e2, bins=[0.0,0.5,1.0,1.5,2.0,2.5])
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative,align='edge')
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("2 Layers, Easy Model")

plt.subplot(1,2,2)
counts, bins = np.histogram(e2h, bins=[0.0,0.5,1.0,1.5,2.0,2.5])
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative,align='edge')
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("2 Layers, Hard Model")
# Out:
# Text(0.5, 1.0, '2 Layers, Hard Model')

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
counts, bins = np.histogram(e3, bins=[0.0,0.5,1.0,1.5,2.0,2.5])
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative,align='edge')
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("3 Layers, Easy Model")

plt.subplot(1,2,2)
counts, bins = np.histogram(e3h, bins=[0.0,0.5,1.0,1.5,2.0,2.5])
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative,align='edge')
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("3 Layers, Hard Model")
# Out:
# Text(0.5, 1.0, '3 Layers, Hard Model')

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
counts, bins = np.histogram(e4, bins=[0.0,0.5,1.0,1.5,2.0,2.5])
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative,align='edge')
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("4 Layers, Easy Model")

plt.subplot(1,2,2)
counts, bins = np.histogram(e4h, bins=[0.0,0.5,1.0,1.5,2.0,2.5])
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative,align='edge')
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("4 Layers, Hard Model")
# Out:
# Text(0.5, 1.0, '4 Layers, Hard Model')

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
counts, bins = np.histogram(e5, bins=[0.0,0.5,1.0,1.5,2.0,2.5])
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative,align='edge')
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("5 Layers, Easy Model")

plt.subplot(1,2,2)
counts, bins = np.histogram(e5h, bins=[0.0,0.5,1.0,1.5,2.0,2.5])
cumulative = counts/np.sum(counts)
plt.bar(bins[:-1], cumulative,align='edge')
plt.ylabel("Normalised Counts")
plt.xlabel("Eigenvalue size")
plt.title("5 Layers, Hard Model")
# Out:
# Text(0.5, 1.0, '5 Layers, Hard Model')
